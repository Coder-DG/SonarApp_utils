# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import json

def show_recording(number):
    fig = plt.figure()
    ax = fig.add_axes([0,0,2,2])
    with open('samples/recording_of_' + str(number), 'r') as f:
        data = json.load(f)
        y = list(int(n) for n in data['data'])
    start_y = 0
    for i in y:
        if y[i] == 0:
            start_y += 1
        else:
            break
    y = y[start_y:]
    x = list(range(len(y)))
    ax.plot(x,y)

show_recording(1)
show_recording(2)
show_recording(3)
